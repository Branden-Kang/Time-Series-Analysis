# %% [markdown]
# [Reference](https://blog.devgenius.io/financial-data-extraction-using-python-710fb03df71b)

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance as yf
import pandas as pd
apple = yf.Ticker("AAPL")

# %%
apple_info = apple.info
apple_info['marketCap']
# Out:
# 2756463820800

# %%
apple.history(period="7d")
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-08-11  170.059998  170.990005  168.190002  168.490005  57149200
# 2022-08-12  169.820007  172.169998  169.399994  172.100006  67946400
# 2022-08-15  171.520004  173.389999  171.350006  173.190002  54091700
# 2022-08-16  172.779999  173.710007  171.660004  173.029999  56377100
# 2022-08-17  172.770004  176.149994  172.570007  174.550003  79542000
# 2022-08-18  173.750000  174.899994  173.119995  174.149994  62290100
# 2022-08-19  173.029999  173.740005  171.309998  171.520004  70211500
#
#             Dividends  Stock Splits
# Date
# 2022-08-11          0             0
# 2022-08-12          0             0
# 2022-08-15          0             0
# 2022-08-16          0             0
# 2022-08-17          0             0
# 2022-08-18          0             0
# 2022-08-19          0             0

# %%
apple.history(period="max")
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100039    0.100474    0.100039    0.100039  469033600
# 1980-12-15    0.095255    0.095255    0.094820    0.094820  175884800
# 1980-12-16    0.088296    0.088296    0.087861    0.087861  105728000
# 1980-12-17    0.090035    0.090470    0.090035    0.090035   86441600
# 1980-12-18    0.092646    0.093081    0.092646    0.092646   73449600
# ...                ...         ...         ...         ...        ...
# 2022-08-15  171.520004  173.389999  171.350006  173.190002   54091700
# 2022-08-16  172.779999  173.710007  171.660004  173.029999   56377100
# 2022-08-17  172.770004  176.149994  172.570007  174.550003   79542000
# 2022-08-18  173.750000  174.899994  173.119995  174.149994   62290100
# 2022-08-19  173.029999  173.740005  171.309998  171.520004   70211500
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
# apple_share_price_data.reset_index(inplace=True)
# apple_share_price_data

# %%
apple.dividends
apple.dividends.plot()

# %%
stock_list=['0005.HK', '0006.HK', '0066.HK', '0700.HK', '2800.HK']
print("stock_list",stock_list)
data = yf.download(stock_list,start="2015-01-01", end="2020-02-21")
print("Data field downloaded")
set(data.columns.get_level_values(0))
data.head(5)
# Out:
# stock_list ['0005.HK', '0006.HK', '0066.HK', '0700.HK', '2800.HK']
# [*********************100%***********************]  5 of 5 completed
# Data field downloaded
#             Adj Close                                                   Close  \
#               0005.HK    0006.HK    0066.HK     0700.HK    2800.HK    0005.HK
# Date
# 2015-01-02  50.670292  40.380539  23.015841  110.276047  24.049999  74.000000
# 2015-01-05  49.917084  39.703468  22.943693  110.960381  23.950001  72.900002
# 2015-01-06  49.129646  39.568047  22.727240  117.314941  23.650000  71.750000
# 2015-01-07  48.616093  40.163872  22.871540  121.616486  23.900000  71.000000
# 2015-01-08  48.753036  40.868023  23.268362  124.451591  24.100000  71.199997
#
#                                                          ...       Open  \
#               0006.HK    0066.HK     0700.HK    2800.HK  ...    0005.HK
# Date                                                     ...
# ...

# %%
print('OPEN data:')
data['Open'].head()
# Out:
# OPEN data:
#               0005.HK    0006.HK    0066.HK     0700.HK    2800.HK
# Date
# 2015-01-02  73.599998  74.849998  31.799999  113.599998  23.900000
# 2015-01-05  73.150002  73.250000  31.650000  113.500000  23.950001
# 2015-01-06  71.800003  74.150002  31.450001  114.000000  23.700001
# 2015-01-07  70.500000  72.699997  31.250000  123.500000  23.600000
# 2015-01-08  71.050003  75.099998  31.950001  127.500000  23.900000

# %%
data = yf.download(stock_list,start="2015-01-01", end="2020-02-21",interval="1wk")
data.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
#             Adj Close                                                Close  \
#               0005.HK    0006.HK    0066.HK     0700.HK 2800.HK    0005.HK
# Date
# 2015-01-01  48.616081  40.163872  22.871540  121.616470   23.90  71.000000
# 2015-01-08  48.513382  41.653435  23.809488  123.180687   24.35  70.849998
# 2015-01-15  48.342197  42.140919  24.062016  125.820282   24.60  70.599998
# 2015-01-22  49.985558  44.361729  24.314539  133.836777   25.10  73.000000
# 2015-01-29  49.574718  44.415878  24.675289  130.903915   24.90  72.400002
#
#                                                       ...       Open  \
#               0006.HK    0066.HK     0700.HK 2800.HK  ...    0005.HK
# Date                                                  ...
# 2015-01-01  74.150002  31.700001  124.400002   23.90  ...  74.000000
# 2015-01-08  76.900002  33.000000  126.000000   24.35  ...  71.050003
# ...

# %%
# Successful Example of getting 1 day data
data = yf.download(stock_list, start="2020-07-07", end="2020-09-14", interval = "1D")
data.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
#             Adj Close                                                   Close  \
#               0005.HK    0006.HK    0066.HK     0700.HK    2800.HK    0005.HK
# Date
# 2020-07-07  36.103233  39.187626  39.779026  512.188232  26.639999  38.650002
# 2020-07-08  34.561958  39.053734  38.835274  538.988770  26.740000  37.000000
# 2020-07-09  34.655365  38.830570  37.844330  558.841003  26.879999  37.099998
# 2020-07-10  34.001492  38.518139  37.514019  542.462891  26.340000  36.400002
# 2020-07-13  34.795483  38.384239  36.994961  537.003540  26.480000  37.250000
#
#                                                      ...       Open  \
#               0006.HK    0066.HK 0700.HK    2800.HK  ...    0005.HK
# Date                                                 ...
# 2020-07-07  43.900002  42.150002   516.0  26.639999  ...  39.400002
# 2020-07-08  43.750000  41.150002   543.0  26.740000  ...  38.500000
# ...

# %%
import pandas as pd
from datetime import date,timedelta
end_date = date.today()
start_date = end_date - timedelta(days=29)
start_date_list = [start_date + timedelta(days=7*i) for i in range(5)]
end_date_list = [start_date_list[i+1] - timedelta(days=1) for i in range(4)] + [end_date]

df_1_min = pd.DataFrame()

for idx in range(5):
  data = yf.download(stock_list,start=start_date_list[idx].strftime("%Y-%m-%d"),end=end_date_list[idx].strftime("%Y-%m-%d"),interval="1m")
  df_1_min = df_1_min.append(data)
df_1_min.head(3)
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
#
# 5 Failed downloads:
# - 0006.HK: No data found for this date range, symbol may be delisted
# - 0005.HK: No data found for this date range, symbol may be delisted
# - 0066.HK: No data found for this date range, symbol may be delisted
# - 2800.HK: No data found for this date range, symbol may be delisted
# - 0700.HK: No data found for this date range, symbol may be delisted
#                            Adj Close                                    \
#                              0005.HK    0006.HK    0066.HK     0700.HK
# 2022-07-25 09:30:00+08:00  48.450001  51.000000  40.750000  329.200012
# ...
