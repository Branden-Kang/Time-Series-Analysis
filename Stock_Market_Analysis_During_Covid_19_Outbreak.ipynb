# %% [markdown]
# [Reference](https://medium.com/@Ketaki_J/stock-market-analysis-4d984a28bc16)

# %%
import pandas as pd
import datetime

# %%
infy = pd.read_csv('https://raw.githubusercontent.com/Ketaki72/Stock-Market-Analysis-During-Covid19/main/Datasets/INFY.NS.csv',header=0,index_col='Date',parse_dates=True)   
tcs = pd.read_csv('https://raw.githubusercontent.com/Ketaki72/Stock-Market-Analysis-During-Covid19/main/Datasets/TCS.NS.csv',header=0,index_col='Date',parse_dates=True)
wipro = pd.read_csv('https://raw.githubusercontent.com/Ketaki72/Stock-Market-Analysis-During-Covid19/main/Datasets/TECHM.NS.csv',header=0,index_col='Date',parse_dates=True)
techm = pd.read_csv('https://raw.githubusercontent.com/Ketaki72/Stock-Market-Analysis-During-Covid19/main/Datasets/WIPRO.NS.csv',header=0,index_col='Date',parse_dates=True)

# %%
infy.head(3)    #see first 3 rows
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-09-03  815.000000  822.400024  812.049988  814.250000  761.677246
# 2019-09-04  810.750000  822.450012  810.250000  821.299988  768.272034
# 2019-09-05  830.099976  837.500000  826.650024  834.049988  780.198853
#
#                Volume
# Date
# 2019-09-03  5647088.0
# 2019-09-04  6199015.0
# 2019-09-05  7926895.0

# %%
infy.tail(3)   #see last 3 rows
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-11-17  1792.550049  1802.000000  1780.699951  1787.449951  1787.449951
# 2021-11-18  1781.599976  1789.449951  1759.000000  1779.400024  1779.400024
# 2021-11-22  1784.000000  1785.400024  1751.150024  1759.400024  1759.400024
#
#                Volume
# Date
# 2021-11-17  4732492.0
# 2021-11-18  4326924.0
# 2021-11-22  6621839.0

# %%
infy.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   547.000000   547.000000   547.000000   547.000000   547.000000
# mean   1103.095156  1115.865082  1091.123674  1103.389856  1077.981406
# std     369.532480   371.013911   366.995023   369.260380   375.899652
# min     509.250000   558.000000   509.250000   526.450012   503.908203
# 25%     754.450012   764.725006   741.575012   755.599976   718.483551
# 50%    1070.000000  1082.000000  1057.500000  1072.300049  1051.533325
# 75%    1372.724976  1386.000000  1359.049988  1372.674988  1346.091064
# max    1829.400024  1848.000000  1794.050049  1822.150024  1806.143311
#
#              Volume
# count  5.470000e+02
# mean   9.364859e+06
# std    7.503160e+06
# min    2.112415e+06
# 25%    5.505670e+06
# 50%    7.369809e+06
# 75%    1.074307e+07
# max    9.043211e+07

# %%
infy.columns  # to see available columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
infy.index #check index to verify the data type
# Out:
# DatetimeIndex(['2019-09-03', '2019-09-04', '2019-09-05', '2019-09-06',
#                '2019-09-09', '2019-09-11', '2019-09-12', '2019-09-13',
#                '2019-09-16', '2019-09-17',
#                ...
#                '2021-11-08', '2021-11-09', '2021-11-10', '2021-11-11',
#                '2021-11-12', '2021-11-15', '2021-11-16', '2021-11-17',
#                '2021-11-18', '2021-11-22'],
#               dtype='datetime64[ns]', name='Date', length=550, freq=None)

# %%
import matplotlib.pyplot as plt   #for visualization
import matplotlib.dates as mdates #for date plotting
import seaborn as sns
sns.set_theme(context='notebook',style='darkgrid')

# %matplotlib inline

# %%
plt.figure(figsize=(12,7))
plt.plot(infy.index ,infy['Adj Close'],color='b') #Plot on Adj close
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Chose the format for date 
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=70)
plt.title('Infosys Stock Price from Sept 2019 - Nov 2021',fontdict={'fontsize':20,'color':'Blue'},pad=10)
plt.xlabel('Date range Sept 2019 - Nov 2021')
plt.ylabel('Stock Prices')
plt.show()

# %%
#Subplots

f,ax = plt.subplots(2,2,figsize =(10,10),sharex = True)
f.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
f.gca().xaxis.set_major_locator(mdates.MonthLocator())

#infy
infy1920 = infy.loc[pd.Timestamp('2020-03-01'):pd.Timestamp('2020-05-01')]
ax[0,0].plot(infy1920.index,infy1920['Adj Close'],'-o',color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=60)
ax[0,0].set_title('INFOSYS');


tcs1920 = tcs.loc[pd.Timestamp('2020-03-01'):pd.Timestamp('2020-05-01')]
ax[0,1].plot(tcs1920.index,tcs1920['Adj Close'],'-o',color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=60)
ax[0,1].set_title('TCS');


wipro1920 = wipro.loc[pd.Timestamp('2020-03-01'):pd.Timestamp('2020-05-01')]
ax[1,1].plot(wipro1920.index,wipro1920['Adj Close'],'-o',color='b')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=60)
ax[1,1].set_title('WIPRO');


techm1920 = techm.loc[pd.Timestamp('2020-03-01'):pd.Timestamp('2020-05-01')]
ax[1,0].plot(techm1920.index,techm1920['Adj Close'],'-o',color='y')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=60)
ax[1,0].set_title('TECH MAHINDRA');
plt.suptitle('Stock Analysis During Covid Breakdown in India',fontsize=20);

# set labels
plt.setp(ax[1,0], xlabel='Data Range from March to May 2020');
plt.setp(ax[1,0], ylabel='Stock Prices');
